# %%
import torch
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from datasets import Set14
from PIL import Image

# %%
ds = Set14(normalize=False) # when training, set normalize to true

# %%
lr, hr = ds[0]
# Out:
# /Users/yifan/.pyenv/versions/3.9.5/lib/python3.9/site-packages/torchvision/transforms/transforms.py:280: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(lr.numpy().transpose((1,2,0)))
ax2.imshow(hr.numpy().transpose((1,2,0)))
