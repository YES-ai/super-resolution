# %%
import torch
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from datasets import Set14
from datasets import Flickr2K
from PIL import Image

# %%
ds = Set14(normalize=False, center_crop=False) # when training, set normalize to true

# %%
lr, hr = ds[0]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(lr.numpy().transpose((1,2,0)))
ax2.imshow(hr.numpy().transpose((1,2,0)))

# %%
ds = Flickr2K(normalize=False, center_crop=True)

# %%
lr, hr = ds[1]
# ds.files

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(lr.numpy().transpose((1,2,0)))
ax2.imshow(hr.numpy().transpose((1,2,0)))
